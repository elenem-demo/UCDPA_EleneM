# %% [markdown]
# # Impoting Data from Kaggle

# %%
import pandas as pd

# %%
df = pd.read_csv("WineQT.csv", index_col = 0)

# %%
df
# Out:
#                volatile acidity  citric acid  residual sugar  chlorides  \
# fixed acidity
# 7.4                       0.700         0.00             1.9      0.076
# 7.8                       0.880         0.00             2.6      0.098
# 7.8                       0.760         0.04             2.3      0.092
# 11.2                      0.280         0.56             1.9      0.075
# 7.4                       0.700         0.00             1.9      0.076
# ...                         ...          ...             ...        ...
# 6.3                       0.510         0.13             2.3      0.076
# 6.8                       0.620         0.08             1.9      0.068
# 6.2                       0.600         0.08             2.0      0.090
# 5.9                       0.550         0.10             2.2      0.062
# 5.9                       0.645         0.12             2.0      0.075
#
#                free sulfur dioxide  total sulfur dioxide  density    pH  \
# fixed acidity
# 7.4                           11.0                  34.0  0.99780  3.51
# 7.8                           25.0                  67.0  0.99680  3.20
# 7.8                           15.0                  54.0  0.99700  3.26
# 11.2                          17.0                  60.0  0.99800  3.16
# 7.4                           11.0                  34.0  0.99780  3.51
# ...                            ...                   ...      ...   ...
# 6.3                           29.0                  40.0  0.99574  3.42
# 6.8                           28.0                  38.0  0.99651  3.42
# 6.2                           32.0                  44.0  0.99490  3.45
# 5.9                           39.0                  51.0  0.99512  3.52
# 5.9                           32.0                  44.0  0.99547  3.57
#
#                sulphates  alcohol  quality    Id
# fixed acidity
# 7.4                 0.56      9.4        5     0
# 7.8                 0.68      9.8        5     1
# 7.8                 0.65      9.8        5     2
# 11.2                0.58      9.8        6     3
# 7.4                 0.56      9.4        5     4
# ...                  ...      ...      ...   ...
# 6.3                 0.75     11.0        6  1592
# 6.8                 0.82      9.5        6  1593
# 6.2                 0.58     10.5        5  1594
# 5.9                 0.76     11.2        6  1595
# 5.9                 0.71     10.2        5  1597
#
# [1143 rows x 12 columns]

# %% [markdown]
# ## Data Sorting, Indexing and Grouping

# %% [markdown]
# ### Sorting multiple values in descending order

# %%
df.sort_values(["alcohol", "quality"], ascending = [False, True])
# Out:
#                volatile acidity  citric acid  residual sugar  chlorides  \
# fixed acidity
# 15.9                       0.36         0.65             7.5      0.096
# 5.2                        0.34         0.00             1.8      0.050
# 5.2                        0.34         0.00             1.8      0.050
# 8.8                        0.46         0.45             2.6      0.065
# 5.0                        0.38         0.01             1.6      0.048
# ...                         ...          ...             ...        ...
# 9.9                        0.50         0.50            13.8      0.205
# 7.9                        0.24         0.40             1.6      0.056
# 10.0                       0.38         0.38             1.6      0.169
# 10.4                       0.61         0.49             2.1      0.200
# 14.3                       0.31         0.74             1.8      0.075
#
#                free sulfur dioxide  total sulfur dioxide  density    pH  \
# fixed acidity
# 15.9                          22.0                  71.0  0.99760  2.98
# 5.2                           27.0                  63.0  0.99160  3.68
# 5.2                           27.0                  63.0  0.99160  3.68
# 8.8                            7.0                  18.0  0.99470  3.32
# 5.0                           26.0                  60.0  0.99084  3.70
# ...                            ...                   ...      ...   ...
# 9.9                           48.0                  82.0  1.00242  3.16
# 7.9                           11.0                  25.0  0.99670  3.32
# 10.0                          27.0                  90.0  0.99914  3.15
# 10.4                           5.0                  16.0  0.99940  3.16
# 14.3                           6.0                  15.0  1.00080  2.86
#
#                sulphates  alcohol  quality    Id
# fixed acidity
# 15.9                0.84     14.9        5   652
# 5.2                 0.79     14.0        6   142
# 5.2                 0.79     14.0        6   144
# 8.8                 0.79     14.0        6   467
# 5.0                 0.75     14.0        6  1270
# ...                  ...      ...      ...   ...
# 9.9                 0.75      8.8        5  1476
# 7.9                 0.87      8.7        6   371
# 10.0                0.65      8.5        5  1436
# 10.4                0.63      8.4        3   517
# 14.3                0.79      8.4        6   544
#
# [1143 rows x 12 columns]

# %% [markdown]
# ### Subsetting based on multiple conditions

# %%
df[df["alcohol"] > 11.0]
# Out:
#                volatile acidity  citric acid  residual sugar  chlorides  \
# fixed acidity
# 4.6                        0.52         0.15             2.1      0.054
# 5.6                        0.50         0.09             2.3      0.049
# 5.2                        0.34         0.00             1.8      0.050
# 5.2                        0.34         0.00             1.8      0.050
# 7.4                        0.62         0.05             1.9      0.068
# ...                         ...          ...             ...        ...
# 6.7                        0.32         0.44             2.4      0.061
# 7.5                        0.31         0.41             2.4      0.065
# 6.3                        0.55         0.15             1.8      0.077
# 5.4                        0.74         0.09             1.7      0.089
# 5.9                        0.55         0.10             2.2      0.062
#
#                free sulfur dioxide  total sulfur dioxide  density    pH  \
# fixed acidity
# 4.6                            8.0                  65.0  0.99340  3.90
# 5.6                           17.0                  99.0  0.99370  3.63
# 5.2                           27.0                  63.0  0.99160  3.68
# 5.2                           27.0                  63.0  0.99160  3.68
# 7.4                           24.0                  42.0  0.99610  3.42
# ...                            ...                   ...      ...   ...
# 6.7                           24.0                  34.0  0.99484  3.29
# 7.5                           34.0                  60.0  0.99492  3.34
# 6.3                           26.0                  35.0  0.99314  3.32
# 5.4                           16.0                  26.0  0.99402  3.67
# 5.9                           39.0                  51.0  0.99512  3.52
#
#                sulphates  alcohol  quality    Id
# fixed acidity
# 4.6                 0.56     13.1        4    45
# 5.6                 0.63     13.0        5   131
# 5.2                 0.79     14.0        6   142
# 5.2                 0.79     14.0        6   144
# 7.4                 0.57     11.5        6   173
# ...                  ...      ...      ...   ...
# 6.7                 0.80     11.6        7  1584
# 7.5                 0.85     11.4        6  1586
# 6.3                 0.82     11.6        6  1590
# 5.4                 0.56     11.6        6  1591
# 5.9                 0.76     11.2        6  1595
#
# [302 rows x 12 columns]

# %% [markdown]
# ### Slicing and .loc

# %%
df.loc[:, ["alcohol", "quality"]]
# Out:
#                alcohol  quality
# fixed acidity
# 7.4                9.4        5
# 7.8                9.8        5
# 7.8                9.8        5
# 11.2               9.8        6
# 7.4                9.4        5
# ...                ...      ...
# 6.3               11.0        6
# 6.8                9.5        6
# 6.2               10.5        5
# 5.9               11.2        6
# 5.9               10.2        5
#
# [1143 rows x 2 columns]

# %%
df.iloc[[1,2,3]]
# Out:
#                volatile acidity  citric acid  residual sugar  chlorides  \
# fixed acidity
# 7.8                        0.88         0.00             2.6      0.098
# 7.8                        0.76         0.04             2.3      0.092
# 11.2                       0.28         0.56             1.9      0.075
#
#                free sulfur dioxide  total sulfur dioxide  density    pH  \
# fixed acidity
# 7.8                           25.0                  67.0   0.9968  3.20
# 7.8                           15.0                  54.0   0.9970  3.26
# 11.2                          17.0                  60.0   0.9980  3.16
#
#                sulphates  alcohol  quality  Id
# fixed acidity
# 7.8                 0.68      9.8        5   1
# 7.8                 0.65      9.8        5   2
# 11.2                0.58      9.8        6   3

# %% [markdown]
# ### Indexing

# %%
df.columns
# Out:
# Index(['volatile acidity', 'citric acid', 'residual sugar', 'chlorides',
#        'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH',
#        'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning - Replacing missing values and filling with the new ones

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 1143 entries, 7.4 to 5.9
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   volatile acidity      1143 non-null   float64
#  1   citric acid           1143 non-null   float64
#  2   residual sugar        1143 non-null   float64
#  3   chlorides             1140 non-null   float64
#  4   free sulfur dioxide   1143 non-null   float64
#  5   total sulfur dioxide  1143 non-null   float64
#  6   density               1143 non-null   float64
#  7   pH                    1143 non-null   float64
#  8   sulphates             1143 non-null   float64
#  9   alcohol               1143 non-null   float64
#  10  quality               1143 non-null   int64
#  11  Id                    1143 non-null   int64
# dtypes: float64(10), int64(2)
# memory usage: 116.1 KB

# %%
df.isna().sum()
# Out:
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               3
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.cleaned=df.dropna(axis=0)
df.cleaned
# Out:
#                volatile acidity  citric acid  residual sugar  chlorides  \
# fixed acidity
# 7.4                       0.700         0.00             1.9      0.076
# 7.8                       0.880         0.00             2.6      0.098
# 7.8                       0.760         0.04             2.3      0.092
# 11.2                      0.280         0.56             1.9      0.075
# 7.4                       0.700         0.00             1.9      0.076
# ...                         ...          ...             ...        ...
# 6.3                       0.510         0.13             2.3      0.076
# 6.8                       0.620         0.08             1.9      0.068
# 6.2                       0.600         0.08             2.0      0.090
# 5.9                       0.550         0.10             2.2      0.062
# 5.9                       0.645         0.12             2.0      0.075
#
#                free sulfur dioxide  total sulfur dioxide  density    pH  \
# fixed acidity
# 7.4                           11.0                  34.0  0.99780  3.51
# 7.8                           25.0                  67.0  0.99680  3.20
# 7.8                           15.0                  54.0  0.99700  3.26
# 11.2                          17.0                  60.0  0.99800  3.16
# 7.4                           11.0                  34.0  0.99780  3.51
# ...                            ...                   ...      ...   ...
# 6.3                           29.0                  40.0  0.99574  3.42
# 6.8                           28.0                  38.0  0.99651  3.42
# 6.2                           32.0                  44.0  0.99490  3.45
# 5.9                           39.0                  51.0  0.99512  3.52
# 5.9                           32.0                  44.0  0.99547  3.57
#
#                sulphates  alcohol  quality    Id
# fixed acidity
# 7.4                 0.56      9.4        5     0
# 7.8                 0.68      9.8        5     1
# 7.8                 0.65      9.8        5     2
# 11.2                0.58      9.8        6     3
# 7.4                 0.56      9.4        5     4
# ...                  ...      ...      ...   ...
# 6.3                 0.75     11.0        6  1592
# 6.8                 0.82      9.5        6  1593
# 6.2                 0.58     10.5        5  1594
# 5.9                 0.76     11.2        6  1595
# 5.9                 0.71     10.2        5  1597
#
# [1140 rows x 12 columns]

# %%
df.filled=df.fillna(df.bfill())
df.filled
# Out:
#                volatile acidity  citric acid  residual sugar  chlorides  \
# fixed acidity
# 7.4                       0.700         0.00             1.9      0.076
# 7.8                       0.880         0.00             2.6      0.098
# 7.8                       0.760         0.04             2.3      0.092
# 11.2                      0.280         0.56             1.9      0.075
# 7.4                       0.700         0.00             1.9      0.076
# ...                         ...          ...             ...        ...
# 6.3                       0.510         0.13             2.3      0.076
# 6.8                       0.620         0.08             1.9      0.068
# 6.2                       0.600         0.08             2.0      0.090
# 5.9                       0.550         0.10             2.2      0.062
# 5.9                       0.645         0.12             2.0      0.075
#
#                free sulfur dioxide  total sulfur dioxide  density    pH  \
# fixed acidity
# 7.4                           11.0                  34.0  0.99780  3.51
# 7.8                           25.0                  67.0  0.99680  3.20
# 7.8                           15.0                  54.0  0.99700  3.26
# 11.2                          17.0                  60.0  0.99800  3.16
# 7.4                           11.0                  34.0  0.99780  3.51
# ...                            ...                   ...      ...   ...
# 6.3                           29.0                  40.0  0.99574  3.42
# 6.8                           28.0                  38.0  0.99651  3.42
# 6.2                           32.0                  44.0  0.99490  3.45
# 5.9                           39.0                  51.0  0.99512  3.52
# 5.9                           32.0                  44.0  0.99547  3.57
#
#                sulphates  alcohol  quality    Id
# fixed acidity
# 7.4                 0.56      9.4        5     0
# 7.8                 0.68      9.8        5     1
# 7.8                 0.65      9.8        5     2
# 11.2                0.58      9.8        6     3
# 7.4                 0.56      9.4        5     4
# ...                  ...      ...      ...   ...
# 6.3                 0.75     11.0        6  1592
# 6.8                 0.82      9.5        6  1593
# 6.2                 0.58     10.5        5  1594
# 5.9                 0.76     11.2        6  1595
# 5.9                 0.71     10.2        5  1597
#
# [1143 rows x 12 columns]

# %%
df.
