# %% [markdown]
# # Impoting Data from Kaggle

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("WineQT.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1140 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %% [markdown]
# ## Data Sorting, Indexing and Grouping

# %% [markdown]
# ### Sorting multiple values in descending order

# %%
df.sort_values(["alcohol", "quality"], ascending = [False, True])
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 462            15.9              0.36         0.65             7.5      0.096
# 96              5.2              0.34         0.00             1.8      0.050
# 98              5.2              0.34         0.00             1.8      0.050
# 329             8.8              0.46         0.45             2.6      0.065
# 898             5.0              0.38         0.01             1.6      0.048
# ...             ...               ...          ...             ...        ...
# 1053            9.9              0.50         0.50            13.8      0.205
# 263             7.9              0.24         0.40             1.6      0.056
# 1023           10.0              0.38         0.38             1.6      0.169
# 368            10.4              0.61         0.49             2.1      0.200
# 388            14.3              0.31         0.74             1.8      0.075
#
# ...

# %% [markdown]
# ### Subsetting based on multiple conditions

# %%
df[df["alcohol"] > 11.0]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 32              4.6              0.52         0.15             2.1      0.054
# 91              5.6              0.50         0.09             2.3      0.049
# 96              5.2              0.34         0.00             1.8      0.050
# 98              5.2              0.34         0.00             1.8      0.050
# 122             7.4              0.62         0.05             1.9      0.068
# ...             ...               ...          ...             ...        ...
# 1133            6.7              0.32         0.44             2.4      0.061
# 1134            7.5              0.31         0.41             2.4      0.065
# 1136            6.3              0.55         0.15             1.8      0.077
# 1137            5.4              0.74         0.09             1.7      0.089
# 1141            5.9              0.55         0.10             2.2      0.062
#
# ...

# %%
df[df["quality"] > 7.0]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 190             7.9              0.35         0.46             3.6      0.078
# 197            10.3              0.32         0.45             6.4      0.073
# 271             5.6              0.85         0.05             1.4      0.045
# 310            12.6              0.31         0.72             2.2      0.072
# 321            11.3              0.62         0.67             5.2      0.086
# 340             9.4              0.30         0.56             2.8      0.080
# 349            10.7              0.35         0.53             2.6      0.070
# 352            10.7              0.35         0.53             2.6      0.070
# 419             5.0              0.42         0.24             2.0      0.060
# 747             9.1              0.40         0.50             1.8      0.071
# 769            10.0              0.26         0.54             1.9      0.083
# ...

# %%
df[df["residual sugar"] > 10.0]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 230            10.0              0.49         0.20            11.0      0.071
# 231            10.0              0.49         0.20            11.0      0.071
# 339            10.6              0.28         0.39            15.5      0.069
# 1022           10.2              0.54         0.37            15.4      0.214
# 1051            9.9              0.50         0.50            13.8      0.205
# 1053            9.9              0.50         0.50            13.8      0.205
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 230                  13.0                  50.0  1.00150  3.16       0.69
# 231                  13.0                  50.0  1.00150  3.16       0.69
# 339                   6.0                  23.0  1.00260  3.12       0.66
# 1022                 55.0                  95.0  1.00369  3.18       0.77
# ...

# %% [markdown]
# ### Slicing and .loc

# %%
df.loc[:, ["alcohol", "quality"]]
# Out:
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1138     11.0        6
# 1139      9.5        6
# 1140     10.5        5
# 1141     11.2        6
# 1142     10.2        5
#
# [1143 rows x 2 columns]

# %% [markdown]
# ### Indexing

# %%
df.columns
# Out:
# Index(['level_0', 'index', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality', 'Id'],
#       dtype='object')

# %%
df.set_index("quality")
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 5                  7.4             0.700         0.00             1.9
# 5                  7.8             0.880         0.00             2.6
# 5                  7.8             0.760         0.04             2.3
# 6                 11.2             0.280         0.56             1.9
# 5                  7.4             0.700         0.00             1.9
# ...                ...               ...          ...             ...
# 6                  6.3             0.510         0.13             2.3
# 6                  6.8             0.620         0.08             1.9
# 5                  6.2             0.600         0.08             2.0
# 6                  5.9             0.550         0.10             2.2
# 5                  5.9             0.645         0.12             2.0
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# ...

# %% [markdown]
# ## Data Cleaning - Replacing missing values and filling with the new ones

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1140 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.isna().sum()
# Out:
# level_0                 0
# index                   0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               3
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.cleaned=df.dropna(axis=0)
df.cleaned
# Out:
#       level_0  index  fixed acidity  volatile acidity  citric acid  \
# 0           0      0            7.4             0.700         0.00
# 1           1      1            7.8             0.880         0.00
# 2           2      2            7.8             0.760         0.04
# 3           3      3           11.2             0.280         0.56
# 4           4      4            7.4             0.700         0.00
# ...       ...    ...            ...               ...          ...
# 1138     1138   1138            6.3             0.510         0.13
# 1139     1139   1139            6.8             0.620         0.08
# 1140     1140   1140            6.2             0.600         0.08
# 1141     1141   1141            5.9             0.550         0.10
# 1142     1142   1142            5.9             0.645         0.12
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                1.9      0.076                 11.0                  34.0
# ...

# %%
df.filled=df.fillna(df.bfill())
df.filled
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.filled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %% [markdown]
# ### Adding a new column

# %%
df["Good Wine"] = df["quality"] > 6
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %% [markdown]
# ### Looping and iterrows

# %%
for i, row in df.iterrows():
    print(i, row["alcohol"], row["Good Wine"])
# Out:
# 0 9.4 False
# 1 9.8 False
# 2 9.8 False
# 3 9.8 False
# 4 9.4 False
# 5 9.4 False
# 6 9.4 False
# 7 10.0 True
# 8 9.5 True
# 9 9.2 False
# 10 9.9 False
# 11 9.1 False
# 12 10.5 True
# 13 9.2 False
# 14 9.7 False
# 15 9.5 False
# 16 9.4 False
# 17 9.7 False
# 18 9.3 False
# 19 9.5 False
# 20 9.4 False
# 21 9.8 False
# 22 10.1 False
# 23 9.8 False
# 24 9.2 False
# 25 9.6 False
# 26 10.8 False
# 27 9.7 True
# 28 10.5 False
# 29 9.3 False
# 30 10.5 False
# 31 10.3 False
# 32 13.1 False
# 33 9.2 False
# 34 9.2 False
# 35 9.4 False
# 36 9.4 False
# 37 9.4 False
# 38 10.2 False
# 39 9.6 False
# 40 10.0 False
# 41 9.4 False
# 42 9.2 False
# 43 9.3 False
# 44 9.8 False
# 45 10.9 False
# 46 10.9 False
# 47 10.7 False
# 48 10.5 False
# 49 9.5 False
# 50 9.2 False
# 51 10.5 False
# 52 10.7 False
# 53 10.1 False
# 54 9.1 False
# 55 9.2 False
# 56 9.1 False
# 57 10.3 False
# 58 10.1 False
# 59 9.9 False
# 60 9.6 False
# 61 9.5 False
# 62 9.0 False
# 63 9.5 False
# 64 9.9 False
# 65 9.6 False
# ...

# %% [markdown]
# ### Grouping

# %%
df.groupby("alcohol")["residual sugar"].count().sort_values(ascending=False).head(30)
# Out:
# alcohol
# 9.5     92
# 9.4     72
# 9.8     57
# 9.2     50
# 10.0    49
# 10.5    48
# 9.3     44
# 9.6     44
# 9.7     42
# 11.0    39
# 9.9     37
# 10.9    35
# 10.1    32
# 10.8    28
# 10.4    28
# 11.4    27
# 10.2    27
# 10.3    27
# 11.2    26
# 11.3    22
# 11.8    21
# 11.5    21
# 10.7    21
# 10.6    19
# 9.0     19
# 12.0    19
# 12.5    18
# 9.1     17
# 11.1    17
# 11.7    17
# Name: residual sugar, dtype: int64

# %% [markdown]
# ### Merging

# %%
df.iloc[[1,2,3,4]]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
df1 = pd.DataFrame(
    {
        "fixed acidity": ["7.8", "7.8", "11.2", "7.4"],
    },
    index=[1, 2, 3, 4],
)

# %%
df1
# Out:
#   fixed acidity
# 1           7.8
# 2           7.8
# 3          11.2
# 4           7.4

# %%
df2 = pd.DataFrame(
    {
        "alcohol": ["9.8", "9.8", "9.8", "9.4"],
    },
    index=[1,2,3,4],
)

# %%
df2
# Out:
#   alcohol
# 1     9.8
# 2     9.8
# 3     9.8
# 4     9.4

# %%
pd.concat([df1,df2], axis=1)
# Out:
#   fixed acidity alcohol
# 1           7.8     9.8
# 2           7.8     9.8
# 3          11.2     9.8
# 4           7.4     9.4

# %%
import numpy as np

# %%
### Converting our dataframe to numpy
np_array1 = df1.to_numpy()
np_array2 = df2.to_numpy()

display(np_array1)
display(np_array2)
# Out:
# array([['7.8'],
#        ['7.8'],
#        ['11.2'],
#        ['7.4']], dtype=object)
# array([['9.8'],
#        ['9.8'],
#        ['9.8'],
#        ['9.4']], dtype=object)

# %%
type(np_array2)
# Out:
# numpy.ndarray

# %%
###Custom Python Function to identify the wine quality

def q(n):
    if n > 6:
        print ("This ia a Good Quality Wine")
    else: 
        print ("This is a Bad Quality Wine")

# %%
q(4)
# Out:
# This is a Bad Quality Wine

# %% [markdown]
# ## Data Visualisation

# %%
sns.relplot(x="alcohol", 
            y="residual sugar", 
            data = df,
            col="quality",
            col_wrap=2,
            kind="scatter",
            hue="quality")

plt.show()

# %%
sns.scatterplot(x="alcohol", 
                y="pH", 
                data = df,
                hue="residual sugar")
plt.show()

# %%
sns.scatterplot(x="alcohol", 
                y="residual sugar", 
                data = df,
                hue="quality")
plt.show()

# %%
sns.scatterplot(x="alcohol", 
            y="fixed acidity", 
            data = df,
            size ="quality",
            hue="quality")
plt.show()

# %%
sns.stripplot(x = "quality", y="total sulfur dioxide", data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='total sulfur dioxide'>

# %%
df[df["total sulfur dioxide"] > 250.0]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 760            7.9               0.3         0.68             8.3       0.05
# 761            7.9               0.3         0.68             8.3       0.05
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 760                 37.5                 278.0  0.99316  3.01       0.51
# 761                 37.5                 289.0  0.99316  3.01       0.51
#
#      alcohol  quality    Id  Good Wine
# 760     12.3        7  1079       True
# 761     12.3        7  1081       True

# %% [markdown]
# ### Importing a Second Dataset

# %%
newdf = pd.read_csv("winequalityN.csv")
newdf
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
newdf.isna().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
newdf.dropna(axis=0)
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6491    red            6.8             0.620         0.08             1.9
# 6492    red            6.2             0.600         0.08             2.0
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
newdf.filled=newdf.fillna(newdf.bfill())
newdf
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
newdf.filled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6497 non-null   float64
#  2   volatile acidity      6497 non-null   float64
#  3   citric acid           6497 non-null   float64
#  4   residual sugar        6497 non-null   float64
#  5   chlorides             6497 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6497 non-null   float64
#  10  sulphates             6497 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
newdf.shape
# Out:
# (6497, 13)

# %%
newdf.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
newdf.tail()
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 6492  red            6.2             0.600         0.08             2.0
# 6493  red            5.9             0.550         0.10             2.2
# 6494  red            6.3             0.510         0.13             2.3
# 6495  red            5.9             0.645         0.12             2.0
# 6496  red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 6492       0.58     10.5        5
# ...

# %%
color1 = pd.DataFrame(
    {
        "white fixed acidity": ["7.0", "6.3", "8.1", "7.2", "7.2"],
    },
    index=[1, 2, 3, 4, 5 ],
)

# %%
color1
# Out:
#   white fixed acidity
# 1                 7.0
# 2                 6.3
# 3                 8.1
# 4                 7.2
# 5                 7.2

# %%
color2 = pd.DataFrame(
    {
        "red fixed acidity": ["6.2", "5.9", "6.3", "5.9", "6.0"],
    },
    index=[1, 2, 3, 4, 5 ],
)

# %%
color2
# Out:
#   red fixed acidity
# 1               6.2
# 2               5.9
# 3               6.3
# 4               5.9
# 5               6.0

# %%
pd.concat([color1,color2], axis=1)
# Out:
#   white fixed acidity red fixed acidity
# 1                 7.0               6.2
# 2                 6.3               5.9
# 3                 8.1               6.3
# 4                 7.2               5.9
# 5                 7.2               6.0

# %%
pd.concat([df1,df2], axis=1)
# Out:
#   fixed acidity alcohol
# 1           7.8     9.8
# 2           7.8     9.8
# 3          11.2     9.8
# 4           7.4     9.4

# %%
acidity = df[["fixed acidity"]].mean()
print(acidity)
# Out:
# fixed acidity    8.311111
# dtype: float64

# %% [markdown]
# ### Guessing that our wine from the original dataset is white :)
